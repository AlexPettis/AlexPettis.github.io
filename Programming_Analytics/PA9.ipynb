# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('Store11_clean.csv')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              52 non-null     object
#  1   Week_Index        52 non-null     int64
#  2   Sales             52 non-null     float64
#  3   Items_Sold        52 non-null     int64
#  4   Labor_Cost        52 non-null     float64
#  5   Gross_Profit      52 non-null     float64
#  6   Bad_Weather_Days  52 non-null     int64
#  7   Item_Labor        52 non-null     float64
# dtypes: float64(4), int64(3), object(1)
# memory usage: 3.4+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              52 non-null     datetime64[ns]
#  1   Week_Index        52 non-null     int64
#  2   Sales             52 non-null     float64
#  3   Items_Sold        52 non-null     int64
#  4   Labor_Cost        52 non-null     float64
#  5   Gross_Profit      52 non-null     float64
#  6   Bad_Weather_Days  52 non-null     int64
#  7   Item_Labor        52 non-null     float64
# dtypes: datetime64[ns](1), float64(4), int64(3)
# memory usage: 3.4 KB

# %%
sns.scatterplot(data = df, x="Sales", y = "Labor_Cost")
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Labor_Cost'>

# %%
sns.lineplot(data = df, x = "Date", y = "Item_Labor")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Item_Labor'>

# %%
sns.displot(df, x = "Gross_Profit")

# %%
sns.barplot(x = "Bad_Weather_Days", y = "Sales", data = df)
# Out:
# <AxesSubplot:xlabel='Bad_Weather_Days', ylabel='Sales'>
